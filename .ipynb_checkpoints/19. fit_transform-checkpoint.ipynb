# %% [markdown]
# <br>
#
# ### fit
# - `fit` : 훈련데이터에서 모델 파라미터를 학습
#
#
# ### transform
# - `transform` : 학습한 파라미터로 데이터를 변환

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 함께 사용되는 메소드: `Imputer`, `PolynomialFeatures()`, `VarianceThreshold` , `MinMaxScaler`, `StandardScaler` , `LabelEncoder`, `OneHotEncoder`
