# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

plt.style.use('seaborn')
sns.set(font_scale=2.5)

# %%
df_train = pd.read_csv('C:\\Users\\user\\TIL\\TIL\\kaggle\\01. titanic\\train.csv')
df_test = pd.read_csv('C:\\Users\\user\\TIL\\TIL\\kaggle\\01. titanic\\test.csv')

# %% [markdown]
# <br>
#
# ## subplot() 2행 1열 구조

# %%
plt.figure(figsize = (10,10))

plt.subplot(211)
plt.subplot(212)

plt.show()

# %%
plt.figure(figsize = (10,10))

# 2행 1열의 첫번째
plt.subplot(2,1,1)
plt.subplot(2,1,2)

plt.show()

# %% [markdown]
# <br>
#
# ## subplot() 1행 2열 구조

# %%
plt.figure(figsize = (10,10))

# 1행 2열 구조
plt.subplot(1,2,1)
plt.subplot(1,2,2)

plt.show()

# %% [markdown]
# <br>
#
# ## subplot 예시 01

# %%
t = np.arange(0, 5, 0.01)

plt.figure(figsize = (10, 12))

plt.subplot(411)
plt.plot(t, np.sqrt(t))
plt.grid()


plt.subplot(423)
plt.plot(t, t**2)
plt.grid()

plt.subplot(424)
plt.plot(t, t**3)
plt.grid()

plt.subplot(413)
plt.plot(t, np.sin(t))
plt.grid()

plt.subplot(414)
plt.plot(t, np.cos(t))


plt.show()

# %% [markdown]
# <br>
#
# ## subplots
# - `subplots`를 활용해 여러 개의 axes 객체를 동시에 생성할 수 있다.
# - `f, ax = plt.subplots(nrows, ncols, sharex, sharey)`
#     - `f` : 전체 사이즈를 말한다. subplot 안에 몇 개의 그래프가 있든지 상관없이 그걸 담는 하나
#     - `ax` : 전체 중 낱개를 말한다. subplot 안에 2개 (a1, a2)의 그래프가 있다면 순서대로 a1 과 a2를 의미한다.
#     - `sharex` : 모든 그래프에서 x 값의 범위가 동일한지 여부
#     - `sharey` : 모든 그래프에서 y 값의 범위가 동일한지 여부

# %%
f, ax = plt.subplots()

print(f)
print(ax)
# Out:
# Figure(432x288)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
f, ax = plt.subplots(2,2)

# %%
print(f)
# Out:
# Figure(432x288)

# %%
print(ax)
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022D6EFFA208>
# ...

# %%
f, ax = plt.subplots(1, 2, figsize = (18, 8))

df_train['Survived'].value_counts().plot.pie(explode = [0, 0.1], autopct = '%1.1f%%', ax = ax[0], shadow = True)
# explode : pie 그래프의 간격 조정
# autopct : pie 그래프 내 표시될 글자 형태

ax[0].set_title('Pie plot - Survived')
ax[0].set_ylabel('')

sns.countplot('Survived', data = df_train, ax = ax[1])
ax[1].set_title('Count plot - Survived')

plt.show()
